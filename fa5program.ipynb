# %% [markdown]
# <a href="https://colab.research.google.com/github/crudajunluiz/fa5programactivity/blob/main/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_total(price, quantity):
    total = price * quantity
    return total

price = float(input("Enter price of item: "))
quantity = int(input("Enter quantity: "))

total_price = calculate_total(price, quantity)

print("Total price:", total_price)
# Out:
# Enter price of item: 50
# Enter quantity: 5
# Total price: 250.0
